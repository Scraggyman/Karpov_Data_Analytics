# %% [markdown]
# # 1

# %% [markdown]
# Начнём с простого: сохраните в переменную age произвольный возраст, выраженный целым числом, а в переменную name – какое-нибудь имя в виде строки.

# %%
age: int = 29
name: str = 'Vadim Belov'

# %% [markdown]
# > Посмотреть разбор задания можно по ссылке https://youtu.be/Y4DSayRRxrM

# %% [markdown]
# # 2

# %% [markdown]
# Создайте список user_info, содержащий 4 элемента в следующем порядке:
# * 2 строки (имя и фамилия пользователя)
# * 1 дробное число (зарплата)
# * 1 целое число (стаж)

# %%
user_info: list = ['Vadim', 'Belov', 179_000.34, 1]

# %% [markdown]
# Посмотреть разбор задания можно по ссылке https://youtu.be/_QJjyRoKvK4

# %% [markdown]
# # 3

# %% [markdown]
# Поместите в переменную first первый (т.е. нулевой) элемент из списка salaries.
#
# Сам список создавать не нужно, он уже находится в переменной salaries. Пример данных, которые могут в нем быть:
#
# [42, 100, 70, 80]

# %%
first = salaries[0]

# %% [markdown]
# Посмотреть разбор задания можно по ссылке https://youtu.be/2zK5DTbmZmE

# %% [markdown]
# # 4

# %% [markdown]
# Добавьте в уже созданный список users элементы 'Voronov' и 42.
#
# Сам список создавать не нужно, он уже находится в переменной users.

# %%
users.append('Voronov')
users.append(42)

# %% [markdown]
# Посмотреть разбор задания можно по ссылке https://youtu.be/41XHFe8jbck

# %% [markdown]
# # 5

# %% [markdown]
# В переменной user_ages содержится список возрастов клиентов. Напишите цикл, выводящий на печать элементы больше 18.
#
# Сам список создавать не нужно, он уже находится в переменной user_ages. Пример данных, которые могут быть в user_ages:
#
# user_ages = [10, 18, 21, 35, 42, 27, 12, 16]
#
# Note: в этом задании эти числа нужно печатать (используйте функцию print).

# %%
for el in user_ages:
    if el > 18:
        print(el)

# %% [markdown]
# Посмотреть разбор задания можно по ссылке https://youtu.be/PNo5kIYcGHE

# %% [markdown]
# # 6

# %% [markdown]
# Напишите программу, проверяющую стаж работы сотрудника. В переменной worker уже содержится список, содержащий значения как во 2-м задании (имя, фамилия, зарплата, стаж). Поместите в переменную status следующую строку:
#
# `user_name user_family is position`
#
# где user_name и user_family — имя и фамилия сотрудника, а position — одно из следующих значений:
#
# 'junior' — стаж меньше 2 лет
# 'middle' — стаж больше либо равен 2 лет и меньше или равен 5
# 'senior' — стаж больше 5 лет
# Пример данных, которые могут быть в worker:
#
# `worker = ['Olya', 'Silyutina', 350000, 3]`
#
# Hint: печатать результат не нужно, просто запишите его в переменную status

# %%
user_name, user_family = worker[:2]
position =  worker[-1]

if position < 2:
    position = 'junior'
elif position <= 5:
    position = 'middle'
else:
    position = 'senior'
status = f'{user_name} {user_family} is {position}'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 user_name, user_family = worker[:2]
#       2 position =  worker[-1]
#       4 if position < 2:
#
# NameError: name 'worker' is not defined

# %% [markdown]
# Посмотреть разбор задания можно по ссылке https://youtu.be/bClp8TYsoE0

# %% [markdown]
# # 7

# %% [markdown]
# В списке values содержатся числовые значения. Создайте список tens и добавьте в него все числа из values, которые делятся на 10 нацело.
#
# Сам список создавать не нужно, он уже находится в переменной values. Пример данных, которые могут быть в values: `values = [12, 134, 10, 47, 100, 20, 50, 160, 210]`

# %%
tens = [el for el in values if el % 10 == 0]

# %% [markdown]
# Посмотреть разбор задания можно по ссылке https://youtu.be/u7QS6D4YEtQ

# %% [markdown]
# # 8

# %% [markdown]
# ⭐️ Задание со звёздочкой! ⭐️
#
# Реализуйте цикл, который пробегается по уже созданному списку workers со значениями как в 2-м и 6-м заданиях и выводит для каждого сотрудника следующую строку (то есть печатает её для каждого элемента списка):
# `user_name user_family is position`
# где user_name и user_family — имя и фамилия сотрудника, а position — одна из следующих строк:
#
# 'junior' — стаж меньше 2 лет
# 'middle' — стаж больше либо равен 2 и меньше или равен 5
# 'senior' — стаж строго больше 5 лет
# Сам список создавать не нужно, он уже находится в переменной workers. Пример данных, которые могут быть в workers: `workers = [['Ivan', 'Ivanov', 100000, 2], ['Petr', 'Petrov', 150000, 2], ['Sidor', 'Sidorov', 200000, 3]]`
#
# Note: в этом задании эти строки нужно печатать (используйте функцию print).

# %%
for worker in workers:
    position = None
    if worker[-1] < 2:
        position = 'junior'
    elif worker[-1] <= 5:
        position = 'middle'
    else:
        position = 'senior'
    print(f'{worker[0]} {worker[1]} is {position}')

# %% [markdown]
# Посмотреть разбор задания можно по ссылке https://youtu.be/-agz_oFFWFY

# %% [markdown]
# # 9

# %% [markdown]
# ⭐️ Задание со звёздочкой! ⭐️
#
# Поместите в список lst числа от 0 (n = 0) до 10 включительно (N = 10) c шагом 2 (dn = 2). Для этого используйте условие while.
#
# Note: необходимо создать переменную lst, а переменные n, N, dn создавать не нужно. Итоговый список печатать тоже не нужно.

# %%
lst = [el for el in range(0, 11, 2)]

# %% [markdown]
# Посмотреть разбор задания можно по ссылке https://youtu.be/R_a_rvvHGYE

# %% [markdown]
# # 10

# %% [markdown]
# На предыдущих шагах вы сталкивались с различными характеристиками пользователей, которые были сохранены в списках. Теперь попробуем собрать нужную информацию в словарь!
#
# Начнем с небольшого, где:
#
# ключом будет название характеристики
# значением – её значение
# В словарь поместите следующую информацию:

# %% [markdown]
# ![изображение.png](attachment:3b1121f7-1d46-4f0e-ae9e-695e751d8a2e.png)

# %%
salaries_dict = {'name': 'Masha', 'surname': 'Volkova', 'age': 25, 'salary': 60000, 'position': 'junior'}

# %% [markdown]
# # 10
